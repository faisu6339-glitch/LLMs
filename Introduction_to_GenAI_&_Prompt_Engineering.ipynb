# %% [markdown]
# <a href="https://colab.research.google.com/github/faisu6339-glitch/LLMs/blob/main/Introduction_to_GenAI_%26_Prompt_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **📝Session Flow📝**:

# %% [markdown]
# * **Learning Objective**
#  - Introduction
#  - Theme
#  - Primary Goals
#
# * **Learning Material**
#   * What is Generative AI?
#   * Large Language Models (LLMs)
#   * Basics of Prompt Engineering: Structuring Prompts to Get Desired Outputs
#   * Activity 1: Fill In The Blanks
#   * Introduction to ChatGPT and How It Can Assist in Assignments
#   * Real-World Generative AI Models – Explore by Category
#   * How Generative AI is different from Machine learning
#   * Activity 2: Fill In The Blanks
#
# * **Summary**
#  - What did you learn?
#  - Best Practices
#  - Shortcomings
#
# * **Enhance your Knowledge**
#  - Additional Reference Paper
#  - Mnemonic
#
# * **Try it Yourself**
#   - Take Home Assignment
#   - Social Engagement

# %% [markdown]
# # **📖 Learning Material 📖**

# %% [markdown]
# #### 📌 **Introduction**
# In this session, participants will be introduced to the rapidly evolving world of **Generative AI**, focusing on how machines can now create human-like content such as text, images, music, and more. The session begins by breaking down what Generative AI is, followed by an introduction to **Large Language Models (LLMs)**—powerful neural networks trained on massive datasets capable of understanding and generating natural language. Participants will also learn the basics of **Prompt Engineering**, a critical skill that involves crafting effective prompts to guide AI systems like ChatGPT in generating accurate and relevant responses. The session then explores how ChatGPT can be leveraged to assist in day-to-day tasks such as completing assignments, brainstorming ideas, or summarizing information. Lastly, we will introduce participants to a variety of real-world generative AI tools categorized by function, and conclude with a discussion on how Generative AI is fundamentally different from traditional Machine Learning approaches.
#
# #### 🎯 **Theme**
# The overarching theme of this session is **"Demystifying Generative AI: From Fundamentals to Real-World Use Cases."** Generative AI is transforming how we interact with technology, enabling machines to act not just as processors of data but as collaborators in creativity, learning, and productivity. This theme is reflected in the way the session unfolds—from explaining the core principles of generative models and LLMs, to showcasing prompt engineering techniques, and then extending into practical tools and comparisons with traditional machine learning. The session aims to build clarity, confidence, and curiosity around how Generative AI works and how it fits into the broader AI ecosystem.
#
# #### 🥅 **Primary Goals**
# The primary goals of this session are fourfold. First, to provide participants with a strong conceptual understanding of **what Generative AI is** and how **LLMs like ChatGPT** function at a high level. Second, to introduce the practical skill of **prompt engineering**, enabling participants to interact more effectively with generative tools and get meaningful outputs. Third, to expose learners to **real-world applications** of Generative AI across various domains—from education and content creation to coding and productivity—so they can begin using these tools in their own work. And fourth, to **clarify the key differences** between generative models and traditional machine learning systems in terms of input-output behavior, training goals, and scope of use, allowing for a more nuanced understanding of where each type of model fits in modern AI solutions.

# %% [markdown]
# # 👨🏻‍🎓 **Learning Objective** 👨🏻‍🎓

# %% [markdown]
# ##  🤖 **Generative AI – A Creative Leap in Artificial Intelligence**

# %% [markdown]
# ### **What is Generative AI?**

# %% [markdown]
# **Generative AI** refers to a class of **artificial intelligence systems** designed to **generate new content**. This content can be **text**, **images**, **audio**, or even **video**. Unlike **traditional AI systems** that might **classify** or **analyze** existing data, generative AI **creates something novel** by **learning patterns** from a dataset and then **producing similar but new data**.

# %% [markdown]
# #### **Examples of Generative AI:**

# %% [markdown]
# **1. Text Generation**
#
# This includes systems that can write **essays**, **articles**, or even **poetry**. For instance, **GPT-3** (the model behind me) can generate **coherent** and **contextually relevant text** based on a given prompt. For example, **ChatGPT** can write essays or answer questions based on what you ask.
#
# **2. Image Generation**
#
# Models like **DALL-E** and **Midjourney** can create **images from textual descriptions**. For example, you could input *"a futuristic cityscape at sunset"* and the AI would generate an image that matches this description.
#
# **3. Music Composition**
# Tools like **OpenAI’s MuseNet** can **compose original music** in various styles based on a given input, like generating a piece of music that combines elements of **classical** and **jazz**.

# %% [markdown]
# ### **Large Language Models (LLMs)**

# %% [markdown]
# **Large Language Models** are a specific type of **generative AI** focused on understanding and generating **human language**. They are trained on **vast amounts of text data** to **predict the next word in a sequence**, allowing them to generate **coherent** and **contextually appropriate** sentences, paragraphs, or even entire articles.

# %% [markdown]
# #### **How They Work**

# %% [markdown]
# **1. Training**
#
# LLMs are trained using a technique called **unsupervised learning**. They process a large **corpus of text** and learn to **predict the likelihood** of a word or phrase appearing in a given context. This involves analyzing the **structure**, **grammar**, and **nuances of language**.
#
# **2. Fine-tuning**
#
# After the initial training, LLMs can be **fine-tuned** on specific datasets to improve performance on particular **tasks** or **domains**.
# For instance, a model might be fine-tuned to specialize in **legal terminology** for use in **legal document analysis**.

# %% [markdown]
# #### **Examples**

# %% [markdown]
# - **ChatGPT**: A chatbot by **OpenAI** that can **chat**, **write essays**, **answer questions**, and more.
# - **Google Bard**: Google’s AI that helps with **generating text** and **answering questions**, similar to ChatGPT.
# - **Meta LLaMA 2**: A model by **Meta** used for various **text-based tasks**, including generating responses and understanding text.
# - **BERT** (*Bidirectional Encoder Representations from Transformers*): Developed by **Google**, BERT improves the **understanding of context** in **search queries**, providing more relevant search results.

# %% [markdown]
# #### **Why It’s Important**

# %% [markdown]
# **1. Enhanced Communication**
#
# LLMs can help **break language barriers** via **real-time translation** or generating content in **multiple languages**.
# **_E.g._,** businesses can use LLMs to translate their websites efficiently.
#
# **2. Content Creation**
#
# They enable **scalable content creation**.
# **_E.g._,** marketing teams can use LLMs to create **social media posts**, **blog articles**, or **ad copy** quickly and affordably.
#
# **3. Personalization**
#
# LLMs can **tailor content** to individual preferences.
# **_E.g._,** **Netflix** recommends shows based on viewing history; similarly, LLMs can generate **personalized messages** or suggestions.
#
# **4. Automation of Routine Tasks**
#
# LLMs can automate tasks like **drafting emails** or **summarizing documents**, saving time and reducing manual effort.
#
# **5. Creative Industries**
#
# In **music**, **art**, and **literature**, generative AI serves as a tool for **creativity**—helping with **brainstorming**, **drafting**, or **exploring styles**.
# **_E.g._,** AI-generated visuals can inspire **designers** or support **advertising campaigns**.
#
# **6. Assistance and Accessibility**
#
# LLMs enable **real-time assistance** via **chatbots**, and support **accessibility** with features like **text-to-speech** and **speech-to-text** for individuals with disabilities.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Basics of Prompt Engineering: Structuring Prompts to Get Desired Outputs**

# %% [markdown]
# #### **What is Prompt Engineering?**

# %% [markdown]
# **Prompt Engineering** is the process of **designing and crafting inputs** (prompts) to get the **best possible output** from an **AI model**, especially those that **generate text** or perform **language-based tasks**. The goal is to **structure your prompt** in a way that **guides the AI** to produce **useful**, **accurate**, or **creative responses**.
#
# > **Simplified Definition:**
# Prompt engineering is figuring out the **best way to ask** an AI a question or give it instructions so it gives you the **best answer**.

# %% [markdown]
# #### **Example**

# %% [markdown]
# Imagine you have a robot that can answer questions:
#
# - If you ask: **“Tell me about birds”**, it might give you a general answer.
# - But if you ask: **“What are the unique features of parrots that help them mimic human speech?”**, you’ll get a **specific and detailed answer**.
#
# 👉 So, **prompt engineering** is like **fine-tuning your question** to get the **most accurate and useful response**.

# %% [markdown]
# #### **Why Prompt Engineering?**

# %% [markdown]
# A **well-designed prompt** can:
#
# - ✅ Improve the **accuracy** of the AI’s responses
# - ✅ Make outputs more **relevant** and **useful**
# - ✅ Help **achieve specific goals** or gather **particular information**

# %% [markdown]
# #### **Key Elements of a Prompt**

# %% [markdown]
# | Element       | Description                                                                                              | Example |
# |---------------|----------------------------------------------------------------------------------------------------------|---------|
# | **Persona**   | Defines the **role** or **perspective** the AI should take                                               | "As a **career counselor**, suggest five tech career paths." |
# | **Instruction** | Clear **task or action** for the AI to perform                                                          | "List the **top three benefits** of regular exercise." |
# | **Context**   | Provides **background** or **scenario**                                                                   | "In the context of a **startup with limited budget**, suggest marketing strategies." |
# | **Input Data** | Specific **details** or **data** to be considered                                                        | "Given that the student scored **85% in math** and **90% in science**, suggest electives." |
# | **Output Indicator** | Specifies **format** or **style** of the response

# %% [markdown]
# #### **Examples of Prompt Engineering for Students**

# %% [markdown]
# ##### **1. Math Problem Explanation**

# %% [markdown]
# - **Prompt**: "Explain how to solve quadratic equations using the quadratic formula, with an example."
# - **Persona**: Math tutor
# - **Instruction**: Explain solving quadratic equations
# - **Context**: Educational tutorial
# - **Input Data**: Example problem
# - **Output Indicator**: Step-by-step solution

# %% [markdown]
# ##### **2. Historical Research**

# %% [markdown]
# - **Prompt**: "Summarize the main causes of the American Civil War using bullet points."
# - **Persona**: History professor
# - **Instruction**: Summarize causes
# - **Context**: American Civil War
# - **Input Data**: Political, economic, and social factors
# - **Output Indicator**: Bullet points

# %% [markdown]
# #### **Techniques in Prompt Engineering**

# %% [markdown]
# - **Specificity**
#   - 🛠 Be precise: use detailed instructions.
#   - ✅ Example: “List 5 advantages of using electric vehicles in urban cities.”
#
# - **Iterative Refinement**
#   - 🔁 Start broad, then tweak based on results.
#   - ✅ Try multiple phrasings until you get the best result.
#
# - **Contextual Information**
#   - 📚 Provide enough background to help the AI.
#   - ✅ Example: “In a startup with 5 employees and $10k budget…”
#
# - **Use of Examples**
#   - 📋 Show what kind of response you want.
#   - ✅ Example: “Write an intro paragraph like this…”

# %% [markdown]
# #### **Pros and Cons of Prompt Engineering**

# %% [markdown]
# ✅ **Pros**
#
# - **Improved Accuracy**: Better results with less trial & error
# - **Efficiency**: Faster answers, less rework
# - **Customization**: Tailored to your task or audience
#
# ❌ **Cons**
#
# - **Learning Curve**: Takes practice to master
# - **Over-Reliance**: May limit AI creativity
# - **Variability**: Output can change between models

# %% [markdown]
# #### **Example: Effective Prompts for Resume Creation**

# %% [markdown]
# - **Personal Information**:
#   "Generate a resume section with fields for name, contact details, LinkedIn."
#
# - **Professional Summary**:
#   "Write a professional summary highlighting skills, achievements, and goals."
#
# - **Work Experience**:
#   "Generate a detailed work experience section with job titles, companies, dates, and bullet points."
#
# - **Education**:
#   "Create an education section with degrees, institutions, dates, and honors."
#
# - **Skills**:
#   "List technical and soft skills, plus certifications, in a resume skills section."

# %% [markdown]
# ### 🔑 **Key Types of Prompts in Prompt Engineering**

# %% [markdown]
# In **prompt engineering**, different types of prompts are used to guide AI models to generate **specific outputs** or perform **varied tasks** effectively.

# %% [markdown]
# **These are three key types of prompts:**
#
# 1. Zero-shot Prompting
# 2. Few-shot Prompting
# 3. Chain-of-Thought (CoT) Prompting

# %% [markdown]
# #### 🧠 **1. Zero-shot Prompting**

# %% [markdown]
# Zero-shot prompting means asking the AI to perform a task or answer a question **without giving any examples**. The AI relies entirely on its **general training knowledge** to respond.
#
# > 📌 **Example:**
# > “Describe the concept of **blockchain technology**.”

# %% [markdown]
# **✅ Use Cases:**
#
# - 🌐 **Translation Tasks**: Asking the model to translate text between languages.
# - 📚 **General Information Requests**: Simple Q&A with no prior examples.
# - 📊 **Simple Classification**: Tasks like sentiment analysis where the model infers categories.

# %% [markdown]
# #### ✌️ **2. Few-shot Prompting**

# %% [markdown]
# Few-shot prompting involves giving the model **a few examples** of the desired input-output format **before** asking it to perform the task. This helps the model better understand the structure and intent.
#
# > 📌 **Example:**
# > “Here are a few examples of product reviews:
# > - Example 1: *The XYZ Phone is excellent for its battery life and camera quality.*
# > - Example 2: *The ABC Laptop is powerful with its high-speed processor and large screen.*
# > Now, write a review for a **new smartwatch**.”

# %% [markdown]
# **✅ Use Cases:**
#
# - 🧩 **Task-specific Applications**: Translation, formatting, summarization with specific patterns.
# - 🎯 **Improving Accuracy**: More reliable outputs using contextual learning.
# - 📝 **Generating Content**: Creating blogs, reviews, or emails in a consistent style.

# %% [markdown]
# #### 🔗 **3. Chain-of-Thought (CoT) Prompting**

# %% [markdown]
# Chain-of-Thought prompting involves **guiding the model** through a **step-by-step reasoning process** to arrive at the final answer. It’s especially useful for **complex or multi-step problems**.
#
# > 📌 **Example (with steps):**
# > Problem: *What is 15 divided by 3?*
# > **Steps:**
# > 1️⃣ Identify the numbers involved in the problem.
# > 2️⃣ Perform the division operation.
# > 3️⃣ State the result.
#
# > Now solve: *What is 72 divided by 8?*
#
# > **🧾 Output:**
# > 1. The numbers involved are 72 and 8.
# > 2. Performing the division: 72 ÷ 8 = 9.
# > 3. ✅ The result is **9**.

# %% [markdown]
# **✅ Use Cases:**
# - 🧮 **Complex Reasoning Tasks**: Multi-step math, logic puzzles, and inference-based queries.
# - 🎓 **Educational Tools**: Useful in tutoring or instructional content with explanations.
# - 🔍 **Problem-Solving**: Ideal where breakdown and reasoning are expected before giving the final output.

# %% [markdown]
# ![image.png](
#
# )

# %% [markdown]
# ### **Activity 1 : Fill in the blanks**

# %% [markdown]
# **1.**
# ________ refers to the process of designing and structuring input queries or instructions to an AI model in a way that helps generate the most accurate, relevant, and useful responses.
# **Hint:** It’s the skill that helps you “ask better questions” to tools like ChatGPT.
#
#
#
# **2.**
# Generative AI models like GPT-3 are trained to create new content by learning patterns in data and then producing similar but ________ outputs.
# **Hint:** These outputs are not copied—they are newly generated and original.
#
#
#
# **3.**
# A model like ChatGPT is an example of a ________ ________ ________, which is trained on large text datasets to generate human-like language.
# **Hint:** It’s a 3-word term often abbreviated as LLM.
#
#
#
# **4.**
# In prompt engineering, ________ refers to including clear background or situation-related details to guide the AI’s response more effectively.
# **Hint:** Think about “setting the scene” so the AI understands the context.
#
#
#
# **5.**
# When you give the AI **no examples** and just ask a question, it is called ________-________ prompting.
# **Hint:** It's a technique where the AI is expected to perform the task with zero prior demonstration.

# %% [markdown]
# #### **Answers**

# %% [markdown]
# 1. Prompt Engineering
# 2. Novel
# 3. Large Language Model
# 4. Context
# 5. Zero-shot

# %% [markdown]
# ## **Introduction to ChatGPT and How It Can Assist in Assignments**

# %% [markdown]
# **ChatGPT** is an advanced **language model** developed by **OpenAI**. It is designed to understand and generate **human-like text** based on user input. Below are some of its core capabilities:

# %% [markdown]
# ### 🔑 **Core Capabilities of ChatGPT**

# %% [markdown]
# - 🧠 **Natural Language Understanding**
#   Comprehends and processes human language to engage in **conversations**, **answer questions**, and **follow instructions**.
#
# - ✍️ **Text Generation**
#   Produces coherent and contextually relevant content — ideal for **essays**, **reports**, and **creative writing**.
#
# - 📚 **Information Retrieval**
#   Provides information across a wide range of topics using its **training data**.
#
# - 🔍 **Problem Solving**
#   Helps with **explanations**, **step-by-step solutions**, and **analytical insights**.

# %% [markdown]
# ### 📚 **Applications of ChatGPT in Various Subjects**

# %% [markdown]
# **1. Math**
#
# - 🧩 **Problem Solving**: Solves math problems (algebra, calculus, geometry) with clear steps.
# - ❓ **Concept Clarification**: Explains math terms and formulas.
# - ✅ *Example*: “Explain the steps to solve a quadratic equation.”
#
# ** 2. Science**
#
# - 🔍 **Conceptual Understanding**: Explains biology, chemistry, and physics concepts.
# - 🧪 **Experiment Ideas**: Suggests science project ideas with guidance.
# - ✅ *Example*: “Summarize Newton’s three laws of motion.”
#
# **3. Literature**
#
# - 📘 **Text Analysis**: Analyzes literature, identifies themes, characters, and plots.
# - ✍️ **Creative Writing**: Assists in drafting poems, essays, and stories.
# - ✅ *Example*: “Explain the central theme of Macbeth.”

# %% [markdown]
# ###💡 **How ChatGPT Can Help with Research, Ideas & Explanations**

# %% [markdown]
# **1. Simplify Research**
#
# - 🧾 **Summarization**: Condenses long texts into key points.
# - 🔍 **Quick Info**: Retrieves facts on demand.
# - ✅ *Example*: “Give me a summary of recent climate change studies.”
#
# **2. Generate Ideas**
#
# - 💡 **Brainstorming**: Suggests ideas for essays, projects, presentations.
# - 🗂 **Outlining**: Creates structured outlines.
# - ✅ *Example*: “Suggest creative ideas for a history project on WW2.”
#
# **3. Provide Explanations**
#
# - 🤓 **Clarification**: Breaks down complex topics into simpler terms.
# - 🔄 **Examples & Analogies**: Uses real-life examples for easier understanding.
# - ✅ *Example*: “Explain quantum entanglement like I’m 12.”

# %% [markdown]
# ### 🎯 **Key Benefits of Using ChatGPT for Student Assignments**

# %% [markdown]
# **1. Enhanced Productivity**
#
# - 📝 **Efficient Writing**: Helps in drafting and editing faster.
# - 🤖 **Automated Help**: Instant answers reduce search time.
#
# **2. Time-Saving**
#
# - 💬 **Quick Solutions**: Instant replies to queries and problems.
# - 🧾 **Streamlined Writing**: Helps generate and structure content quickly.
#
# **3. Better Understanding of Complex Topics**
#
# - 📘 **Clear Explanations**: Provides thorough and customized answers.
# - 🎯 **Personalized Learning**: Adapts to your learning style and pace.

# %% [markdown]
# ### **Prompt Example: Resume Builder for Data Science**

# %% [markdown]
# > Act as a **Resume Builder** who creates resumes tailored to specific job descriptions.
#
# - I am looking for resume for Data Science profile
# - I have 4 years of experience in Data Science
# - I have worked in 2 companies and I want to show this Data Science experience in these 2 companies.
# - Make sure you add some real time experience and use cases according to the job description in the resume
# - please provide this resume in a proper resume format.
#
# Wait for me to provide you a job description.
#
# 🛑 **Note**: *Please wait for me to provide the job description before finalizing the resume content.*

# %% [markdown]
# Act as a Resume Builder who creates resumes tailored to specific job descriptions.
#
# - Profile: Data Science
# - Experience: 4 years
# - Previous Employment: Worked at 2 companies
# - Requirements:
#     - Include real-time experiences and use cases relevant to Data Science roles.
#     - Tailor the resume according to the provided job description.
#     - Format the resume properly with standard sections including Contact Information, Professional Summary, Work Experience, Education, Skills, and Certifications.
#
# Note: Please wait for me to provide the job description before finalizing the resume content.

# %% [markdown]
#  ## **Real-World Generative AI Models – Explore by Category**

# %% [markdown]
# Explore real-world **Generative AI (GenAI)** tools across domains like text, image, code, audio, and video generation.

# %% [markdown]
# ###  **Text Generation Models (Chatbots & Writers)**

# %% [markdown]
# | **Model** | **Developer** | **Description** | **Explore** |
# |-----------|---------------|-----------------|-------------|
# | **ChatGPT (GPT-4)** | OpenAI | Conversational AI for writing, coding, tutoring, etc. | [chat.openai.com](https://chat.openai.com) |
# | **Claude 3** | Anthropic | Safe, helpful, and honest AI assistant. | [claude.ai](https://claude.ai) |
# | **Gemini (Bard)** | Google | Multimodal chatbot with Google integration. | [gemini.google.com](https://gemini.google.com) |
# | **Mistral / Mixtral** | Mistral AI | Open-source performant LLMs. | [mistral.ai](https://mistral.ai) |
# | **LLaMA 2 / 3** | Meta | Meta’s open LLMs for research & enterprise. | [ai.meta.com/llama](https://ai.meta.com/llama/) |
# | **Cohere Command R+** | Cohere | Enterprise-focused retrieval-augmented LLM. | [cohere.com](https://cohere.com) |
# | **Perplexity AI** | Perplexity | AI-powered search with citations. | [perplexity.ai](https://www.perplexity.ai) |
# | **Pi (Personal AI)** | Inflection AI | Friendly, empathetic assistant AI. | [heypi.com](https://heypi.com) |
# | **YouChat** | You.com | Search-integrated AI chatbot. | [you.com](https://you.com) |

# %% [markdown]
# ### 🎨 **Image Generation Models**

# %% [markdown]
# | **Model** | **Developer** | **Description** | **Explore** |
# |-----------|---------------|-----------------|-------------|
# | **DALL·E 3** | OpenAI | Text-to-image model with fine detail. | [chat.openai.com](https://chat.openai.com) |
# | **Midjourney** | Midjourney | Artistic and photorealistic image generation. | [midjourney.com](https://www.midjourney.com) |
# | **Stable Diffusion** | Stability AI | Open-source image generation. | [clipdrop.co/stable-diffusion](https://clipdrop.co/stable-diffusion) |
# | **Adobe Firefly** | Adobe | Commercial-safe AI art generation. | [firefly.adobe.com](https://firefly.adobe.com) |
# | **Leonardo AI** | Leonardo | Game asset and concept art generator. | [leonardo.ai](https://leonardo.ai) |

# %% [markdown]
# ### 👨‍💻 **Code Generation Models**

# %% [markdown]
# | **Model** | **Developer** | **Description** | **Explore** |
# |-----------|---------------|-----------------|-------------|
# | **GitHub Copilot** | GitHub + OpenAI | AI code assistant in VS Code and JetBrains. | [github.com/features/copilot](https://github.com/features/copilot) |
# | **CodeWhisperer** | Amazon | AWS-native AI coding tool. | [aws.amazon.com/codewhisperer](https://aws.amazon.com/codewhisperer/) |
# | **Replit Ghostwriter** | Replit | AI pair programmer in Replit IDE. | [replit.com](https://replit.com) |
# | **Phind** | Phind | Coding-focused AI search & Q&A. | [phind.com](https://phind.com) |
# | **StarCoder** | Hugging Face / BigCode | Open-source code LLM. | [huggingface.co/bigcode](https://huggingface.co/bigcode) |

# %% [markdown]
# ### 🎧 **Audio & Music Generation Models**

# %% [markdown]
# | **Model** | **Developer** | **Description** | **Explore** |
# |-----------|---------------|-----------------|-------------|
# | **ElevenLabs** | ElevenLabs | Realistic voice synthesis & cloning. | [elevenlabs.io](https://www.elevenlabs.io) |
# | **Voicemod AI Voices** | Voicemod | Real-time AI voice changer. | [voicemod.net](https://www.voicemod.net) |
# | **Suno AI (Bark, Chirp)** | Suno AI | Text-to-song generation. | [suno.com](https://www.suno.com) |
# | **MusicGen** | Meta | Music generation from text prompts. | [huggingface.co/facebook/musicgen](https://huggingface.co/facebook/musicgen) |
# | **Soundraw** | Soundraw | Royalty-free AI music generation. | [soundraw.io](https://soundraw.io) |

# %% [markdown]
# ### 🎥 **Video Generation & Editing Models**

# %% [markdown]
# | **Model** | **Developer** | **Description** | **Explore** |
# |-----------|---------------|-----------------|-------------|
# | **Runway Gen-2** | Runway | Text-to-video, video-to-video, AI editing. | [runwayml.com](https://runwayml.com) |
# | **Pika Labs** | Pika | Video generation from text and images. | [pika.art](https://www.pika.art) |
# | **Synthesia** | Synthesia | AI avatars create videos from scripts. | [synthesia.io](https://www.synthesia.io) |
# | **HeyGen** | HeyGen | Talking head avatars and explainer videos. | [heygen.com](https://www.heygen.com) |
# | **Kaiber** | Kaiber | AI video storytelling and animation. | [kaiber.ai](https://www.kaiber.ai) |

# %% [markdown]
# ### 🔄 **Multimodal GenAI Models (Text + Image + Code)**

# %% [markdown]
# | **Model** | **Developer** | **Description** | **Explore** |
# |-----------|---------------|-----------------|-------------|
# | **GPT-4 with Vision** | OpenAI | Combines image and text input. | [chat.openai.com](https://chat.openai.com) |
# | **Gemini 1.5** | Google DeepMind | Processes text, images, PDFs, and code. | [gemini.google.com](https://gemini.google.com) |
# | **Claude 3 Opus** | Anthropic | Handles large documents, image reasoning. | [claude.ai](https://claude.ai) |
# | **IDEFICS** | Hugging Face | Open-source vision-language model. | [huggingface.co/HuggingFaceM4](https://huggingface.co/HuggingFaceM4) |

# %% [markdown]
# ### 💻 **Open-Source & Local-Run LLMs**

# %% [markdown]
# - 🔹 **Ollama** – Run LLaMA 3, Mistral locally: [ollama.com](https://ollama.com)
# - 🔹 **LM Studio** – Chat with local models: [lmstudio.ai](https://lmstudio.ai)
# - 🔹 **GPT4All** – Local chat with downloaded LLMs: [gpt4all.io](https://gpt4all.io)
# - 🔹 **Hugging Face Transformers** – Explore 1000s of open-source LLMs: [huggingface.co/models](https://huggingface.co/models)

# %% [markdown]
# ### 📌 **Bonus: Where to Explore More GenAI Demos**
#
# - 🧪 **Hugging Face Spaces**: [huggingface.co/spaces](https://huggingface.co/spaces)
# - 📊 **Papers with Code – Generative Models**: [paperswithcode.com](https://paperswithcode.com)
# - 🧰 **FutureTools AI Directory**: [futuretools.io](https://www.futuretools.io)

# %% [markdown]
# ## **How Generative AI is different from Machine learning**

# %% [markdown]
# | **Aspect**            | **Machine Learning (ML)**                              | **Generative AI (GenAI)**                                       |
# | --------------------- | ------------------------------------------------------ | --------------------------------------------------------------- |
# | **Goal**              | Analyze data to make predictions or decisions          | Create new content like text, images, audio, or code            |
# | **Output Type**       | Labels, numbers, categories                            | Human-like content (text, image, music, etc.)                   |
# | **Data Type**         | Primarily structured/tabular data                      | Mostly unstructured data (text, image, etc.)                    |
# | **Examples**          | Fraud detection, price prediction, spam classification | Chatbots, image generation, music composition                   |
# | **Learning Approach** | Supervised or unsupervised learning                    | Mostly self-supervised learning (pretraining on large datasets) |
# | **Common Algorithms** | Linear Regression, Decision Trees, SVM                 | Transformers (e.g., GPT, DALL·E, LLaMA)                         |
# | **Use Case Focus**    | Understanding and decision-making                      | Creativity and content creation                                 |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Activity 2 : Fill in the blanks**

# %% [markdown]
# 1. ChatGPT is a type of ________developed by OpenAI that can understand and generate human-like text based on the input it receives.
#
# 2. One of ChatGPT's key capabilities is ________________, which allows it to produce essays, emails, and other written content in a coherent and context-aware way.
#
# 3. Generative AI is different from traditional machine learning because it focuses on creating ________ like text, images, or audio instead of just making predictions or classifications.
#
# 4. In prompt engineering, giving a model **no examples** and expecting it to perform a task is called ________________prompting.
#
# 5. A _______________________ is a type of generative AI model trained on massive amounts of text to understand and generate human language.

# %% [markdown]
# #### **Answers**

# %% [markdown]
# 1. Language Model
# 2. Text Generation
# 3. Content
# 4. Zero-shot
# 5. Large Language Model

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ## 📚 **What Did You Learn? 🤔**

# %% [markdown]
# In today’s session, we explored the fascinating world of **Generative AI** — a form of artificial intelligence that doesn’t just analyze data but actually creates new content like text, images, and even music. We began by understanding what Generative AI is and how it stands apart from traditional machine learning. We then dived into **Large Language Models (LLMs)** like ChatGPT, discovering how they are trained on massive text datasets to understand and generate human-like language. Through the concept of **Prompt Engineering**, we learned how the way we frame our questions or instructions can significantly impact the quality of AI-generated responses. We also explored how **ChatGPT** can assist students in various subjects, helping with research, summarization, creative writing, and problem-solving. By browsing through a wide range of **real-world GenAI tools**, from image creators like DALL·E to code assistants like GitHub Copilot, we saw the versatility and growing impact of generative models. Altogether, this session provided a solid foundation to not only understand Generative AI but also apply it meaningfully in academics, projects, and creative tasks.

# %% [markdown]
# ##✅ **Best Practices for Using Generative AI**

# %% [markdown]
# 1. **Ask clear and specific questions** – The better your prompt, the better the answer.
# 2. **Give the AI a role** – e.g., “Act as a teacher and explain…”
# 3. **Add context** – Provide details to get accurate results.
# 4. **Refine your prompts** – Try again if the first answer isn’t right.
# 5. **Check the output** – Always review and fact-check AI responses.
# 6. **Use the right tool** – Pick ChatGPT for text, DALL·E for images, etc.
# 7. **Protect your data** – Don’t share personal or sensitive information.
# 8. **Save useful prompts** – Reuse good prompts for similar tasks.

# %% [markdown]
# ## ⚠️ **Shortcomings of Generative AI**

# %% [markdown]
# 1. **May give incorrect or misleading information**
#    – AI doesn't always know the right answer.
#
# 2. **Lacks real understanding**
#    – It generates text based on patterns, not true knowledge.
#
# 3. **Can be biased**
#    – AI may reflect biases found in its training data.
#
# 4. **Not always up to date**
#    – Many models don’t have real-time or current knowledge.
#
# 5. **Overconfident in wrong answers**
#    – AI may sound confident even when it’s wrong.
#
# 6. **Privacy concerns**
#    – Should not be used to share personal or sensitive data.
#
# 7. **Not a replacement for human thinking**
#    – Use AI as a helper, not a decision-maker.

# %% [markdown]
# # **🧠 Enhance Your Knowledge 🧠**

# %% [markdown]
# ##🤖🌲**Mnemonic**🕵️‍♂️🦉

# %% [markdown]
# Use this to remember how to get better results from ChatGPT:
#
# - **C – Context** → Give background info
# - **L – Language** → Be clear and specific
# - **E – Examples** → Show what kind of answer you want
# - **A – Ask Clearly** → Say exactly what you need
# - **R – Refine** → Try again if needed
#
# **Chat** → Use ChatGPT like a helpful assistant!

# %% [markdown]
# ###📖**Additional Reference Paper**📖

# %% [markdown]
# - [Attention Is All You Need (Transformer Paper)](https://arxiv.org/abs/1706.03762)
# - [Language Models are Few-Shot Learners (GPT-3)](https://arxiv.org/abs/2005.14165)
# - [Training Language Models to Follow Instructions (InstructGPT)](https://arxiv.org/abs/2203.02155)
# - [A Survey of Prompt Engineering Techniques](https://arxiv.org/abs/2302.11382)
# - [An Overview of Large Language Models (LLMs)](https://arxiv.org/abs/2303.18223)
# - [DALL·E: Creating Images from Text](https://openai.com/research/dall-e)
# - [ChatGPT: Optimizing Language Models for Dialogue](https://openai.com/research/chatgpt)
# - [Chain-of-Thought Prompting Elicits Reasoning in LLMs](https://arxiv.org/abs/2201.11903)

# %% [markdown]
# # **Try it Yourself**

# %% [markdown]
# ### ✅ **Task 1: Prompt Writing Practice**
# **Goal:** Learn to craft effective prompts for academic use.
#
# 📝 **Instructions:**
# Use ChatGPT to complete the following:
#
# - Write a prompt that asks ChatGPT to explain a science concept like **photosynthesis** to a 12-year-old.
# - Now rewrite the same prompt for a **college student studying biology**.
#
# 🎯 **Compare the outputs**. What changes do you notice in tone, detail, and structure?

# %% [markdown]
# ### ✅ **Task 2: Real-World Application**
# **Goal:** Use generative AI to support your assignments or learning.
#
# 📝 **Instructions:**
# Pick any one of the following tasks and use ChatGPT to assist you:
#
# - Generate a **3-point summary** of an article or chapter you’ve read.
# - Create a **resume summary** for a Data Science role with 2–4 years of experience.
# - Draft an **introduction paragraph** for an essay on climate change.
#
# 🎯 **Reflect:** How did prompt structure affect the quality of the result? Try changing the prompt to see how the response improves.
